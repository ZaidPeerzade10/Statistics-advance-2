# %% [markdown]
# # Statistic advance 2

# %% [markdown]
# 1. What is hypothesis testing in statistics
#    - Hypothesis testing is a statistical method used to make decisions or inferences about population parameters based on sample data.
#    - It involves stating a null and alternative hypothesis and using statistical tests to determine which is more likely.
#    - The process helps in assessing whether observed data significantly deviates from what was expected under the null hypothesis.
#
# 2. What is the null hypothesis, and how does it differ from the alternative hypothesis
#    - The null hypothesis (H₀) is a default assumption that there is no effect or no difference in the population.
#    - The alternative hypothesis (H₁ or Ha) contradicts the null, suggesting there is an effect or a difference.
#    - Hypothesis testing determines whether the sample data provides enough evidence to reject the null in favor of the alternative.
#
# 3. What is the significance level in hypothesis testing, and why is it important
#    - The significance level (denoted as α) is the probability of rejecting the null hypothesis when it is actually true (Type I error).
#    - Common values are 0.05 or 0.01, and it defines the threshold for how extreme the data must be to consider the result statistically significant.
#    - It's important because it controls the likelihood of making a false positive conclusion.
#
# 4. What does a P-value represent in hypothesis testing
#    - A P-value is the probability of obtaining results as extreme as, or more extreme than, those observed in the sample data, assuming the null hypothesis is true.
#    - It quantifies the evidence against the null hypothesis.
#    - A small P-value indicates strong evidence against H₀.
#
# 5. How do you interpret the P-value in hypothesis testing
#    - If the P-value is less than or equal to the significance level (α), we reject the null hypothesis, suggesting the result is statistically significant.
#    - If it's greater than α, we fail to reject the null, meaning there isn't enough evidence to support the alternative.
#    - It doesn't prove a hypothesis but indicates strength of evidence.
#
# 6. What are Type 1 and Type 2 errors in hypothesis testing
#    - A Type 1 error occurs when the null hypothesis is true but is incorrectly rejected.
#    - A Type 2 error happens when the null hypothesis is false but is incorrectly not rejected.
#    - Type 1 is a false positive, and Type 2 is a false negative.
#
# 7. What is the difference between a one-tailed and a two-tailed test in hypothesis testing
#    - A one-tailed test checks for an effect in only one direction (either greater than or less than a value).
#    - A two-tailed test looks for an effect in both directions, checking for any significant difference regardless of direction.
#    - The choice depends on the research question and hypothesis.
#
# 8. What is the Z-test, and when is it used in hypothesis testing
#    - The Z-test is used to determine whether two population means are different when the standard deviations are known and the sample size is large (typically n > 30).
#    - It assumes that the data follows a normal distribution.
#    - It's often used for comparing sample and population means.
#
# 9. How do you calculate the Z-score, and what does it represent in hypothesis testing
#    - The Z-score is calculated as Z=𝑋−𝜇/σ, where X is the sample value, μ is the population mean, and σ is the standard deviation.
#    - It represents how many standard deviations a value is from the mean.
#    - In hypothesis testing, it helps determine how extreme a value is under the null hypothesis.
#
# 10. What is the T-distribution, and when should it be used instead of the normal distribution
#    - The T-distribution is similar to the normal distribution but has heavier tails, making it more appropriate for small sample sizes or unknown population standard deviation.
#    - As sample size increases, it approaches the normal distribution.
#    - It's used in T-tests and other scenarios where Z-tests are not suitable.
#
# 11. What is the difference between a Z-test and a T-test
#    - A Z-test is used when the population standard deviation is known and the sample size is large.
#    - A T-test is used when the population standard deviation is unknown and the sample size is small.
#    - Both tests assess whether sample means differ significantly from population means or from each other.
#
# 12. What is the T-test, and how is it used in hypothesis testing
#    - A T-test compares the means of two groups to determine if they are statistically different from each other.
#    - It's used when the population standard deviation is unknown and the sample size is small.
#    - There are different types, such as one-sample, two-sample, and paired T-tests, depending on the study design.
#
# 13. What is the relationship between Z-test and T-test in hypothesis testing
#    - Both Z-tests and T-tests are used to test hypotheses about means, but they differ in their assumptions.
#    - Z-tests assume known population standard deviation and large sample size, while T-tests are used for smaller samples and unknown standard deviation.
#    - As sample size increases, results from both tests converge.
#
# 14. What is a confidence interval, and how is it used to interpret statistical results
#    - A confidence interval provides a range of values within which the true population parameter is likely to fall, based on sample data.
#    - It gives an estimate with a specific level of confidence (e.g., 95%).
#    - A wider interval indicates more uncertainty, while a narrower one shows more precision.
#
# 15. What is the margin of error, and how does it affect the confidence interval
#    - The margin of error is the amount added and subtracted from the sample estimate to create a confidence interval.
#    - It reflects the uncertainty in the estimate due to sampling variability.
#    - A larger margin of error results in a wider confidence interval, indicating less precision.
#
# 16. How is Bayes' Theorem used in statistics, and what is its significance
#    - Bayes' Theorem updates the probability of a hypothesis based on new evidence.
#    - It combines prior probability and likelihood to compute a posterior probability.
#    - It's especially useful in fields like medical testing, spam filtering, and machine learning for probabilistic inference.
#
# 17. What is the Chi-square distribution, and when is it used
#    - The Chi-square distribution is used for categorical data to test relationships between variables or the goodness of fit.
#    - It's skewed right and depends on degrees of freedom.
#    - It's commonly used in Chi-square tests for independence and goodness-of-fit tests.
#
# 18. What is the Chi-square goodness of fit test, and how is it applied
#    - The Chi-square goodness of fit test determines whether a sample distribution matches an expected distribution.
#    - It compares observed frequencies to expected frequencies across categories.
#    - If the difference is large, it suggests the data does not fit the expected distribution.
#
# 19. What is the F-distribution, and when is it used in hypothesis testing
#    - The F-distribution is used to compare two variances and is the basis for the ANOVA test.
#    - It's positively skewed and depends on two degrees of freedom: one for the numerator and one for the denominator.
#    - It helps assess whether groups have significantly different variances.
#
# 20. What is an ANOVA test, and what are its assumptions
#    - ANOVA (Analysis of Variance) tests whether there are significant differences between the means of three or more groups.
#    - It assumes independence of observations, normally distributed groups, and equal variances.
#    - It uses the F-statistic to evaluate the null hypothesis that all group means are equal.
#
# 21. What are the different types of ANOVA tests
#    - The main types of ANOVA are one-way ANOVA (one independent variable), two-way ANOVA (two independent variables), and repeated measures ANOVA (same subjects tested across conditions).
#    - Each type is used based on the experimental design and the number of factors involved.
#
# 22. What is the F-test, and how does it relate to hypothesis testing
#    - The F-test compares variances to determine if they are significantly different.
#    - It is used in ANOVA and regression analysis to assess the overall significance of a model.
#    - The F-statistic helps determine whether to reject the null hypothesis that variances or group effects are equal.

# %% [markdown]
# # Practicle 1

# %%
# 1. Write a Python program to generate a random variable and display its value
import random
print("Random variable:", random.random())
# Out:
# Random variable: 0.7041649828489844

# %%
# 2. Generate a discrete uniform distribution using Python and plot the probability mass function (PMF)
import matplotlib.pyplot as plt
from scipy.stats import randint
import numpy as np

x = np.arange(1, 7)
pmf = randint.pmf(x, 1, 7)
plt.bar(x, pmf)
plt.title("Discrete Uniform PMF (1-6)")
plt.xlabel("Value")
plt.ylabel("Probability")
plt.show()

# %%
# 3. Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution
from scipy.stats import bernoulli

def bernoulli_pdf(p, x):
    return bernoulli.pmf(x, p)

print("Bernoulli PDF (p=0.6, x=1):", bernoulli_pdf(0.6, 1))
# Out:
# Bernoulli PDF (p=0.6, x=1): 0.6

# %%
# 4. Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram
from scipy.stats import binom

data = binom.rvs(n=10, p=0.5, size=1000)
plt.hist(data, bins=range(12), edgecolor='black', alpha=0.7)
plt.title("Binomial Distribution Histogram (n=10, p=0.5)")
plt.xlabel("Number of Successes")
plt.ylabel("Frequency")
plt.show()

# %%
# 5. Create a Poisson distribution and visualize it using Python
from scipy.stats import poisson

x = np.arange(0, 15)
pmf = poisson.pmf(x, mu=4)
plt.bar(x, pmf)
plt.title("Poisson Distribution (λ=4)")
plt.xlabel("Value")
plt.ylabel("Probability")
plt.show()

# %%
# 6. Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete uniform distribution
cdf = randint.cdf(x, 1, 7)
plt.step(x, cdf, where='post')
plt.title("CDF of Discrete Uniform Distribution (1-6)")
plt.xlabel("Value")
plt.ylabel("Cumulative Probability")
plt.grid(True)
plt.show()

# %%
# 7. Generate a continuous uniform distribution using NumPy and visualize it
data = np.random.uniform(0, 1, 1000)
plt.hist(data, bins=20, density=True, edgecolor='black')
plt.title("Continuous Uniform Distribution [0,1]")
plt.xlabel("Value")
plt.ylabel("Density")
plt.show()

# %%
# 8. Simulate data from a normal distribution and plot its histogram
data = np.random.normal(loc=0, scale=1, size=1000)
plt.hist(data, bins=30, edgecolor='black')
plt.title("Normal Distribution Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %%
# 9. Write a Python function to calculate Z-scores from a dataset and plot them
from scipy.stats import zscore

def plot_z_scores(data):
    z_scores = zscore(data)
    plt.plot(z_scores, marker='o')
    plt.title("Z-Scores of Dataset")
    plt.xlabel("Index")
    plt.ylabel("Z-Score")
    plt.grid(True)
    plt.show()

plot_z_scores(np.random.normal(0, 1, 100))

# %%
# 10. Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution
samples = [np.mean(np.random.exponential(scale=2, size=30)) for _ in range(1000)]
plt.hist(samples, bins=30, edgecolor='black')
plt.title("Central Limit Theorem on Exponential Data")
plt.xlabel("Sample Mean")
plt.ylabel("Frequency")
plt.show()

# %%
# 11. Simulate multiple samples from a normal distribution and verify the Central Limit Theorem
samples = [np.mean(np.random.normal(loc=5, scale=2, size=40)) for _ in range(1000)]
plt.hist(samples, bins=30, edgecolor='black')
plt.title("CLT with Normal Distribution Samples")
plt.xlabel("Sample Mean")
plt.ylabel("Frequency")
plt.show()

# %%
# 12. Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1)
from scipy.stats import norm

x = np.linspace(-4, 4, 1000)
pdf = norm.pdf(x)
plt.plot(x, pdf)
plt.title("Standard Normal Distribution")
plt.xlabel("Z")
plt.ylabel("Density")
plt.grid(True)
plt.show()

# %%
# 13. Generate random variables and calculate their corresponding probabilities using the binomial distribution
data = binom.rvs(n=20, p=0.4, size=10)
probabilities = binom.pmf(data, n=20, p=0.4)
print("Data:", data)
print("Probabilities:", probabilities)
# Out:
# Data: [ 2  8  9  7 12  7  8  7  8  9]
# Probabilities: [0.00308742 0.17970579 0.15973848 0.16588227 0.03549744 0.16588227
#  0.17970579 0.16588227 0.17970579 0.15973848]

# %%
# 14. Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal distribution
x = 75
mean = 70
std = 5
z = (x - mean) / std
prob = norm.cdf(z)
print(f"Z-score for {x} is {z}, Cumulative Probability: {prob}")
# Out:
# Z-score for 75 is 1.0, Cumulative Probability: 0.8413447460685429

# %%
# 15. Implement hypothesis testing using Z-statistics for a sample dataset
sample = np.random.normal(loc=52, scale=5, size=30)
pop_mean = 50
sample_mean = np.mean(sample)
sample_std = np.std(sample, ddof=1)
z_stat = (sample_mean - pop_mean) / (sample_std / np.sqrt(len(sample)))
p_value = 2 * (1 - norm.cdf(abs(z_stat)))
print("Z-statistic:", z_stat)
print("P-value:", p_value)
# Out:
# Z-statistic: 2.2684663435657164
# P-value: 0.023300798118074395

# %%
# 16. Create a confidence interval for a dataset using Python and interpret the result
from scipy.stats import t

data = np.random.normal(100, 15, 50)
mean = np.mean(data)
sem = np.std(data, ddof=1) / np.sqrt(len(data))
ci = t.interval(0.95, df=len(data)-1, loc=mean, scale=sem)
print("95% Confidence Interval:", ci)
# Out:
# 95% Confidence Interval: (np.float64(99.3397490566877), np.float64(107.60948736873611))

# %%
# 17. Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean
data = np.random.normal(60, 10, 100)
mean = np.mean(data)
sem = np.std(data, ddof=1) / np.sqrt(len(data))
ci = t.interval(0.95, df=99, loc=mean, scale=sem)
print("Mean:", mean)
print("95% Confidence Interval for Mean:", ci)
# Out:
# Mean: 59.4640462228432
# 95% Confidence Interval for Mean: (np.float64(57.62891197928818), np.float64(61.29918046639822))

# %%
# 18. Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution
x = np.linspace(-3, 3, 100)
pdf = norm.pdf(x)
plt.plot(x, pdf)
plt.title("PDF of Normal Distribution")
plt.xlabel("X")
plt.ylabel("Density")
plt.grid(True)
plt.show()

# %%
# 19. Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution
cdf_val = poisson.cdf(5, mu=3)
print("CDF of Poisson(λ=3) at x=5:", cdf_val)
# Out:
# CDF of Poisson(λ=3) at x=5: 0.9160820579686966

# %%
# 20. Simulate a random variable using a continuous uniform distribution and calculate its expected value
data = np.random.uniform(10, 20, 1000)
expected_value = np.mean(data)
print("Expected value of uniform distribution [10, 20]:", expected_value)
# Out:
# Expected value of uniform distribution [10, 20]: 15.01451352530483

# %%
# 21. Write a Python program to compare the standard deviations of two datasets and visualize the difference
data1 = np.random.normal(50, 5, 100)
data2 = np.random.normal(50, 10, 100)
std1 = np.std(data1)
std2 = np.std(data2)
print("Standard deviation of dataset 1:", std1)
print("Standard deviation of dataset 2:", std2)
plt.boxplot([data1, data2], labels=["Data1", "Data2"])
plt.title("Standard Deviation Comparison")
plt.grid(True)
plt.show()
# Out:
# Standard deviation of dataset 1: 5.083495345998982
# Standard deviation of dataset 2: 9.978878146944218
# <ipython-input-21-ba9d52491a19>:8: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([data1, data2], labels=["Data1", "Data2"])

# %%
# 22. Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution
data = np.random.normal(100, 20, 1000)
range_val = np.ptp(data)
q75, q25 = np.percentile(data, [75, 25])
iqr = q75 - q25
print("Range:", range_val)
print("Interquartile Range (IQR):", iqr)
# Out:
# Range: 112.02022691005847
# Interquartile Range (IQR): 26.76789210626498

# %%
# 23. Implement Z-score normalization on a dataset and visualize its transformation
data = np.random.normal(10, 2, 100)
normalized = zscore(data)
plt.hist(normalized, bins=20, edgecolor='black')
plt.title("Z-score Normalized Data")
plt.xlabel("Z-score")
plt.ylabel("Frequency")
plt.show()

# %%
# 24. Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal distribution
from scipy.stats import skew, kurtosis

data = np.random.normal(0, 1, 1000)
print("Skewness:", skew(data))
print("Kurtosis:", kurtosis(data))
# Out:
# Skewness: 0.10226754798756611
# Kurtosis: 0.2076009838046451

# %% [markdown]
# # Practical 2

# %%
# 1. Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and interpret the results.
import numpy as np
from scipy import stats

data = np.random.normal(loc=52, scale=10, size=30)
pop_mean = 50
z_stat, p_value = stats.ttest_1samp(data, pop_mean)
print("Z-statistic:", z_stat, "| P-value:", p_value)
# Out:
# Z-statistic: -1.3621491706129758 | P-value: 0.18363810197513006

# %%
# 2. Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python.
sample = np.random.normal(100, 15, 50)
z_stat, p_value = stats.ttest_1samp(sample, 95)
print("Z-statistic:", z_stat, "| P-value:", p_value)
# Out:
# Z-statistic: 1.6019839468036647 | P-value: 0.11558704706186095

# %%
# 3. Implement a one-sample Z-test using Python to compare the sample mean with the population mean.
def one_sample_z_test(data, pop_mean, pop_std):
    n = len(data)
    sample_mean = np.mean(data)
    z = (sample_mean - pop_mean) / (pop_std / np.sqrt(n))
    p = 2 * (1 - stats.norm.cdf(abs(z)))
    return z, p

data = np.random.normal(100, 10, 50)
z, p = one_sample_z_test(data, 95, 10)
print("Z:", z, "| P:", p)
# Out:
# Z: 2.665735577847864 | P: 0.007682008849539956

# %%
# 4. Perform a two-tailed Z-test using Python and visualize the decision region on a plot.
import matplotlib.pyplot as plt

z_stat = 2.1
x = np.linspace(-4, 4, 1000)
y = stats.norm.pdf(x)

plt.plot(x, y)
plt.fill_between(x, y, where=(x < -1.96) | (x > 1.96), color='red', alpha=0.3, label="Rejection region")
plt.axvline(z_stat, color='blue', linestyle='--', label=f'Z = {z_stat:.2f}')
plt.legend()
plt.title("Two-Tailed Z-Test Decision Region")
plt.show()

# %%
# 5. Create a Python function that calculates and visualizes Type 1 and Type 2 errors during hypothesis testing.
def plot_errors(mu0=0, mu1=1, sigma=1, alpha=0.05, n=30):
    x = np.linspace(-4, 4, 1000)
    se = sigma / np.sqrt(n)
    critical = stats.norm.ppf(1 - alpha)
    plt.plot(x, stats.norm.pdf(x, mu0, se), label="Null (Type I)")
    plt.plot(x, stats.norm.pdf(x, mu1, se), label="Alternative (Type II)")
    plt.axvline(critical, color='red', linestyle='--', label=f'Critical Z = {critical:.2f}')
    plt.fill_between(x, stats.norm.pdf(x, mu0, se), where=(x > critical), alpha=0.3, color='red', label='Type I Error')
    plt.fill_between(x, stats.norm.pdf(x, mu1, se), where=(x <= critical), alpha=0.3, color='blue', label='Type II Error')
    plt.legend()
    plt.title("Type I and Type II Errors")
    plt.show()

plot_errors()

# %%
# 6. Write a Python program to perform an independent T-test and interpret the results.
group1 = np.random.normal(100, 10, 30)
group2 = np.random.normal(105, 10, 30)
t_stat, p_val = stats.ttest_ind(group1, group2)
print("Independent T-test:", t_stat, "| P-value:", p_val)
# Out:
# Independent T-test: -0.9788265350091875 | P-value: 0.3317309664538718

# %%
# 7. Perform a paired sample T-test using Python and visualize the comparison results.
before = np.random.normal(50, 5, 30)
after = before + np.random.normal(2, 3, 30)
t_stat, p_val = stats.ttest_rel(before, after)
print("Paired T-test:", t_stat, "| P-value:", p_val)
plt.boxplot([before, after], labels=['Before', 'After'])
plt.title("Paired Sample Comparison")
plt.show()
# Out:
# Paired T-test: -3.325706346010243 | P-value: 0.0024019268942663172
# <ipython-input-31-23d9a878a599>:6: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([before, after], labels=['Before', 'After'])

# %%
# 8. Simulate data and perform both Z-test and T-test, then compare the results using Python.
sample = np.random.normal(100, 10, 30)
pop_mean = 95
# Z-test (assuming population std = 10)
z_stat, p_z = one_sample_z_test(sample, pop_mean, 10)
# T-test
t_stat, p_t = stats.ttest_1samp(sample, pop_mean)
print("Z-test:", z_stat, "| P:", p_z)
print("T-test:", t_stat, "| P:", p_t)
# Out:
# Z-test: 2.8569538557479426 | P: 0.004277280155962071
# T-test: 3.331753383143182 | P: 0.0023646254404755115

# %%
# 9. Write a Python function to calculate the confidence interval for a sample mean and explain its significance.
def confidence_interval(data, confidence=0.95):
    n = len(data)
    mean = np.mean(data)
    se = stats.sem(data)
    margin = stats.t.ppf((1 + confidence) / 2., n-1) * se
    return mean - margin, mean + margin

ci = confidence_interval(np.random.normal(100, 15, 50))
print("Confidence Interval:", ci)
# Out:
# Confidence Interval: (np.float64(95.94509543997111), np.float64(104.24593675721033))

# %%
# 10. Write a Python program to calculate the margin of error for a given confidence level using sample data.
def margin_of_error(data, confidence=0.95):
    se = stats.sem(data)
    n = len(data)
    moe = stats.t.ppf((1 + confidence) / 2., n-1) * se
    return moe

data = np.random.normal(70, 12, 40)
print("Margin of Error:", margin_of_error(data))
# Out:
# Margin of Error: 4.466035159087639

# %%
# 11. Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process.
def bayes_theorem(prior_A, likelihood_B_given_A, prior_not_A, likelihood_B_given_not_A):
    numerator = likelihood_B_given_A * prior_A
    denominator = numerator + likelihood_B_given_not_A * prior_not_A
    posterior = numerator / denominator
    return posterior

# Example
P_A = 0.01  # Disease prevalence
P_B_given_A = 0.99  # Test true positive
P_not_A = 0.99
P_B_given_not_A = 0.05  # False positive
print("Posterior Probability (Disease given Positive Test):", bayes_theorem(P_A, P_B_given_A, P_not_A, P_B_given_not_A))
# Out:
# Posterior Probability (Disease given Positive Test): 0.16666666666666669

# %%
# 12. Perform a Chi-square test for independence between two categorical variables in Python.
import pandas as pd
import scipy.stats as stats

data = [[10, 20, 30], [6, 9, 17]]
chi2, p, dof, expected = stats.chi2_contingency(data)
print("Chi-square:", chi2, "| p-value:", p, "| Expected frequencies:\n", expected)
# Out:
# Chi-square: 0.27157465150403504 | p-value: 0.873028283380073 | Expected frequencies:
#  [[10.43478261 18.91304348 30.65217391]
#  [ 5.56521739 10.08695652 16.34782609]]

# %%
# 13. Calculate the expected frequencies for a Chi-square test based on observed data.
observed = np.array([[20, 15], [30, 35]])
chi2, p, dof, expected = stats.chi2_contingency(observed)
print("Expected Frequencies:\n", expected)
# Out:
# Expected Frequencies:
#  [[17.5 17.5]
#  [32.5 32.5]]

# %%
# 14. Perform a goodness-of-fit test using Python to compare the observed data to an expected distribution.
observed = [50, 30, 20]
expected = [40, 40, 20]
chi2_stat, p_value = stats.chisquare(f_obs=observed, f_exp=expected)
print("Chi-square Goodness-of-fit:", chi2_stat, "| p-value:", p_value)
# Out:
# Chi-square Goodness-of-fit: 5.0 | p-value: 0.0820849986238988

# %%
# 15. Simulate and visualize the Chi-square distribution and discuss its characteristics.
import matplotlib.pyplot as plt

df = 4
x = np.linspace(0, 20, 1000)
y = stats.chi2.pdf(x, df)

plt.plot(x, y, label=f'df={df}')
plt.title("Chi-Square Distribution")
plt.xlabel("Value")
plt.ylabel("Probability Density")
plt.legend()
plt.grid()
plt.show()

# %%
# 16. Implement an F-test using Python to compare the variances of two random samples.
sample1 = np.random.normal(100, 10, 50)
sample2 = np.random.normal(100, 20, 50)

f_stat = np.var(sample1, ddof=1) / np.var(sample2, ddof=1)
dof1, dof2 = len(sample1) - 1, len(sample2) - 1
p_value = 1 - stats.f.cdf(f_stat, dof1, dof2)
print("F-statistic:", f_stat, "| p-value:", p_value)
# Out:
# F-statistic: 0.22205872538812146 | p-value: 0.999999743299452

# %%
# 17. Perform an ANOVA test to compare means between multiple groups and interpret the results.
group1 = np.random.normal(100, 10, 30)
group2 = np.random.normal(110, 10, 30)
group3 = np.random.normal(105, 10, 30)

f_stat, p_val = stats.f_oneway(group1, group2, group3)
print("ANOVA F-statistic:", f_stat, "| p-value:", p_val)
# Out:
# ANOVA F-statistic: 5.047394927221974 | p-value: 0.008434604103568845

# %%
# 18. Perform a one-way ANOVA test using Python and plot the results.
plt.boxplot([group1, group2, group3], labels=["Group1", "Group2", "Group3"])
plt.title("One-way ANOVA Comparison")
plt.show()
# Out:
# <ipython-input-42-4ca9c2f54478>:2: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([group1, group2, group3], labels=["Group1", "Group2", "Group3"])

# %%
# 19. Write a function to check ANOVA assumptions: normality, independence, equal variance.
from scipy.stats import shapiro, levene

def check_anova_assumptions(*groups):
    print("Normality Test:")
    for i, g in enumerate(groups):
        print(f"Group {i+1} Shapiro-Wilk:", shapiro(g))

    print("\nHomogeneity of Variance Test:")
    print("Levene’s test:", levene(*groups))

check_anova_assumptions(group1, group2, group3)
# Out:
# Normality Test:
# Group 1 Shapiro-Wilk: ShapiroResult(statistic=np.float64(0.9765043750669624), pvalue=np.float64(0.7269684699953647))
# Group 2 Shapiro-Wilk: ShapiroResult(statistic=np.float64(0.9685466512347667), pvalue=np.float64(0.5002138330304713))
# Group 3 Shapiro-Wilk: ShapiroResult(statistic=np.float64(0.9843493671458272), pvalue=np.float64(0.9256007068884347))
#
# Homogeneity of Variance Test:
# Levene’s test: LeveneResult(statistic=np.float64(0.32870380467271076), pvalue=np.float64(0.7207462715864964))

# %%
# 20. Perform a two-way ANOVA test using Python and visualize results.
import statsmodels.api as sm
from statsmodels.formula.api import ols

df = pd.DataFrame({
    'value': np.concatenate([group1, group2, group3]),
    'treatment': ['A']*30 + ['B']*30 + ['C']*30,
    'block': (['X']*10 + ['Y']*10 + ['Z']*10)*3
})

model = ols('value ~ C(treatment) + C(block) + C(treatment):C(block)', data=df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print(anova_table)
# Out:
#                             sum_sq    df         F    PR(>F)
# C(treatment)            952.131474   2.0  5.028594  0.008738
# C(block)                 50.553774   2.0  0.266995  0.766348
# C(treatment):C(block)   486.797495   4.0  1.285488  0.282590
# Residual               7668.410259  81.0       NaN       NaN

# %%
# 21. Visualize the F-distribution and discuss its use in hypothesis testing.
x = np.linspace(0.01, 5, 1000)
dfn, dfd = 5, 20
y = stats.f.pdf(x, dfn, dfd)
plt.plot(x, y, label=f'df1={dfn}, df2={dfd}')
plt.title("F-distribution")
plt.xlabel("F")
plt.ylabel("Density")
plt.grid()
plt.legend()
plt.show()

# %%
# 22. Perform one-way ANOVA in Python and visualize the results with boxplots.
groupA = np.random.normal(60, 10, 30)
groupB = np.random.normal(65, 10, 30)
groupC = np.random.normal(70, 10, 30)
f_stat, p_val = stats.f_oneway(groupA, groupB, groupC)
print("One-Way ANOVA:", f_stat, "| p-value:", p_val)
plt.boxplot([groupA, groupB, groupC], labels=['A', 'B', 'C'])
plt.title("One-Way ANOVA Boxplot")
plt.show()
# Out:
# One-Way ANOVA: 13.971881695976805 | p-value: 5.469807625342003e-06
# <ipython-input-46-0a470d7e33e9>:7: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([groupA, groupB, groupC], labels=['A', 'B', 'C'])

# %%
# 23. Simulate random data from normal distribution and perform hypothesis test to evaluate means.
data = np.random.normal(50, 5, 40)
t_stat, p_val = stats.ttest_1samp(data, 52)
print("T-test:", t_stat, "| P-value:", p_val)
# Out:
# T-test: -2.588229475588014 | P-value: 0.013485168989419889

# %%
# 24. Perform a hypothesis test for population variance using Chi-square distribution and interpret results.
sample = np.random.normal(60, 8, 30)
sample_var = np.var(sample, ddof=1)
pop_var = 64
chi2 = (len(sample) - 1) * sample_var / pop_var
p_val = 1 - stats.chi2.cdf(chi2, df=len(sample) - 1)
print("Chi-square statistic:", chi2, "| P-value:", p_val)
# Out:
# Chi-square statistic: 24.192173809895337 | P-value: 0.7194002422294876

# %%
# 25. Perform a Z-test for comparing proportions between two datasets or groups.
from statsmodels.stats.proportion import proportions_ztest

count = np.array([45, 30])
nobs = np.array([100, 100])
z_stat, p_val = proportions_ztest(count, nobs)
print("Proportion Z-test:", z_stat, "| P-value:", p_val)
# Out:
# Proportion Z-test: 2.1908902300206647 | P-value: 0.02845973691631055

# %%
# 26. Implement an F-test for comparing variances and visualize the results.
var1 = np.var(groupA, ddof=1)
var2 = np.var(groupB, ddof=1)
f = var1 / var2
df1, df2 = len(groupA) - 1, len(groupB) - 1
p = 1 - stats.f.cdf(f, df1, df2)
print("F-test stat:", f, "| P-value:", p)

# Visualization
x = np.linspace(0.01, 5, 1000)
plt.plot(x, stats.f.pdf(x, df1, df2))
plt.axvline(f, color='red', linestyle='--', label='Observed F')
plt.legend()
plt.title("F-test Distribution")
plt.show()
# Out:
# F-test stat: 0.9032743259333849 | P-value: 0.6069986500366888

# %%
# 27. Perform a Chi-square test for goodness of fit with simulated data and analyze results.
import numpy as np
from scipy import stats

observed = np.array([25, 30, 45])
expected_proportions = np.array([1/3, 1/3, 1/3])  # Equal proportions
expected = expected_proportions * observed.sum()  # Scale to match total observed

chi2_stat, p_val = stats.chisquare(f_obs=observed, f_exp=expected)
print("Goodness-of-Fit Chi-square:", chi2_stat, "| P-value:", p_val)
# Out:
# Goodness-of-Fit Chi-square: 6.500000000000002 | P-value: 0.038774207831721974
